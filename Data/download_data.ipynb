# %%
import imdlib as imd
"""
# install imdlib python library
# you should be connected to internet for downloading the data
#-9999 value is for no data in saved csv file
# This code will convert the IMD gridded data to csv file
if you have data already downloaded then create folder named rain/tmax/tmin inside any folder and
copy yearly data files in the respective folder and rename yearly data file as year name i.e 1951.GRD 1952.GRD etc and
comment the line imd.get_data(variable,start_yr) and run the code it will convert the binary .GRD data into csv file
"""
start_yr = 1901 # give starting year from which you want to download/convert data: 1901 ownwards for rainfall, 1951 for tmax and tmin
end_yr = 2018 # give ending year upto which you want to download/convert data
variable = 'rain' # give variable name (rain for rainfall at 0.25 deg, tmax or tmin for rainfall, min or max temperature at 1 deg resolution)
file_format = 'yearwise' # other option (None), which will assume deafult imd naming convention
file_dir = '/mnt/c/Users/nikhil/Documents/sem5/projects_papers/rainfall/data' # this path should be same as mentioned in previous line
imd.get_data(variable,start_yr,end_yr,file_format,file_dir) # this will download the data from imd website
data = imd.open_data(variable, start_yr, end_yr,'yearwise', file_dir) # this will open the data downloaded and saved in the location mentioned in previous line
if variable == 'rain':
    grid_size = 0.25 # grid spacing in deg
    y_count = 129 # no of grids in y direction
    x_count = 135 # no of grids in x direction
    x = 66.5 # starting longitude taken from control file (.ctl)
    y = 6.5 # starting latitude taken from control file (.ctl)
elif variable == 'tmax' or variable == 'tmin':
    grid_size = 1 # grid spacing in deg
    y_count = 31 # no of grids in y direction
    x_count = 31 # no of grids in x direction
    x = 67.5 # starting longitude taken from control file (.ctl)
    y = 7.5 # starting latitude taken from control file (.ctl)

#print(grid_size,x_count, y_count, x, y)
data
data.shape
np_array = data.data
#print(np_array[0,0,0])
#xr_objecct = data.get_xarray()
#type(xr_objecct)
#xr_objecct.mean('time').plot()
years_no = (end_yr - start_yr) + 1
#print(years_no)
day = 0
for yr in range(0,years_no):
    f = open("rain_csv"+str(start_yr+yr)+"_"+str(variable)+".csv",'w') # just change the path where you want to save csv file
    if ((start_yr+yr) % 4 == 0) and ((start_yr+yr) % 100 != 0):  # check for leap year
        days = 366
        count = yr + days
    elif ((start_yr+yr) % 4 == 0) and ((start_yr+yr) % 100 == 0) and ((start_yr+yr) % 400 == 0):
        days = 366
        count = yr + days
    else:
        days = 365
        count = yr + days

    day = day + days

    f.write("X,Y,")
    for d in range(0, days):
        f.write(str(d+1))
        f.write(",")
    f.write("\n")
    #print(np_array[364,0,0])
    for j in range(0, y_count):

        for i in range(0, x_count):

            f.write(str((i * grid_size) + x))
            f.write(",")
            f.write(str((j * grid_size) + y))
            f.write(",")
            time = 0
            for k in range(day-days, day):

                val = np_array[k,i,j]
                if val == 99.9000015258789 or val == -999:
                    f.write(str(-9999))
                    f.write(",")
                else:
                    f.write(str(val))
                    f.write(",")


            f.write("\n")
    print("File for " + str(start_yr + yr) + "_" + str(variable) + " is saved")
print("CSV conversion successful !")
# Out:
# Downloading: rain for year 1901
# Downloading: rain for year 1902
# Downloading: rain for year 1903
# Downloading: rain for year 1904
# Downloading: rain for year 1905
# Downloading: rain for year 1906
# Downloading: rain for year 1907
# Downloading: rain for year 1908
# Downloading: rain for year 1909
# Downloading: rain for year 1910
# Downloading: rain for year 1911
# Downloading: rain for year 1912
# File for 1909_rain is saved
# File for 1910_rain is saved
# File for 1911_rain is saved
# File for 1912_rain is saved
# File for 1913_rain is saved
# File for 1914_rain is saved
# File for 1915_rain is saved
# File for 1916_rain is saved
# File for 1917_rain is saved
# File for 1918_rain is saved
# File for 1919_rain is saved
# File for 1920_rain is saved
# File for 1921_rain is saved
# File for 1922_rain is saved
# File for 1923_rain is saved
# File for 1924_rain is saved
# File for 1925_rain is saved
# File for 1926_rain is saved
# File for 1927_rain is saved
# File for 1928_rain is saved
# File for 1929_rain is saved
# File for 1930_rain is saved
# File for 1931_rain is saved
# File for 1932_rain is saved
# File for 1933_rain is saved
# File for 1934_rain is saved
# File for 1935_rain is saved
# File for 1936_rain is saved
# File for 1937_rain is saved
# File for 1938_rain is saved
# File for 1939_rain is saved
# File for 1940_rain is saved
# File for 1941_rain is saved
# File for 1942_rain is saved
# File for 1943_rain is saved
# File for 1944_rain is saved
# File for 1945_rain is saved
# File for 1946_rain is saved
# File for 1947_rain is saved
# File for 1948_rain is saved
# File for 1949_rain is saved
# File for 1950_rain is saved
# File for 1951_rain is saved
# File for 1952_rain is saved
# File for 1953_rain is saved
# File for 1954_rain is saved
# File for 1955_rain is saved
# File for 1956_rain is saved
# File for 1957_rain is saved
# File for 1958_rain is saved
# File for 1959_rain is saved
# File for 1960_rain is saved
# File for 1961_rain is saved
# File for 1962_rain is saved
# File for 1963_rain is saved
# File for 1964_rain is saved
# File for 1965_rain is saved
# File for 1966_rain is saved
# File for 1967_rain is saved
# File for 1968_rain is saved
# File for 1969_rain is saved
# File for 1970_rain is saved
# File for 1971_rain is saved
# File for 1972_rain is saved
# File for 1973_rain is saved
# File for 1974_rain is saved
# File for 1975_rain is saved
# File for 1976_rain is saved
# File for 1977_rain is saved
# File for 1978_rain is saved
# File for 1979_rain is saved
# File for 1980_rain is saved
# File for 1981_rain is saved
# File for 1982_rain is saved
# File for 1983_rain is saved
# File for 1984_rain is saved
# File for 1985_rain is saved
# File for 1986_rain is saved
# File for 1987_rain is saved
# File for 1988_rain is saved
# File for 1989_rain is saved
# File for 1990_rain is saved
# File for 1991_rain is saved
# File for 1992_rain is saved
# File for 1993_rain is saved
# File for 1994_rain is saved
# File for 1995_rain is saved
# File for 1996_rain is saved
# File for 1997_rain is saved
# File for 1998_rain is saved
# File for 1999_rain is saved
# File for 2000_rain is saved
# File for 2001_rain is saved
# File for 2002_rain is saved
# File for 2003_rain is saved
# File for 2004_rain is saved
# File for 2005_rain is saved
# File for 2006_rain is saved
# File for 2007_rain is saved
# File for 2008_rain is saved
# File for 2009_rain is saved
# File for 2010_rain is saved
# File for 2011_rain is saved
# File for 2012_rain is saved
# File for 2013_rain is saved
# File for 2014_rain is saved
# File for 2015_rain is saved
# File for 2016_rain is saved
# File for 2017_rain is saved
# File for 2018_rain is saved
# CSV conversion successful !

# %%
# import pandas as pd

# %%
# file1 = pd.read_csv("rain_csv1996_rain.csv")
# file2 = pd.read_csv("rain_csv1996_nikhil.csv")

# %%
# file1.head()

# %%
# file2.head()

# %%
# file1.compare(file2)

# %%
# file1 == file2

# %%
# file1.iloc[17413]

# %%
# file2.iloc[17413]
